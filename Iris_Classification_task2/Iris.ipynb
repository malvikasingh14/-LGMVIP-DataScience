# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
iris=pd.read_csv("iris.csv")
print(iris)
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 6 columns]

# %%
#to check for presence of null
print(iris.isna().sum())
print(iris.describe())
# Out:
# Unnamed: 0      0
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
n = len(iris[iris['Species'] == 'setosa'])
print("No of Setosa:",n)
# Out:
# No of Setosa: 50

# %%
n2 = len(iris[iris['Species'] == 'virginica'])
print("No of Virginica:",n2)
# Out:
# No of Virginica: 50

# %%
n3 = len(iris[iris['Species'] == 'versicolor'])
print("No of Versicolor:",n3)
# Out:
# No of Versicolor: 50

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
l = ['Setosa','Virginica','Versicolor']
s = [50,50,50]
ax.pie(s, labels = l,autopct='%1.2f%%')
plt.show()

# %%
iris.hist()

plt.show()

# %%
X = iris['Sepal.Length'].values.reshape(-1,1)
y = iris['Sepal.Width'].values.reshape(-1,1)
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.scatter(X,y,color='r')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='Petal.Length',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='Petal.Width',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='Sepal.Length',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='Sepal.Width',data=iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Sepal.Width'>

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# c:\users\91981\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20928/357946195.py in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 log_reg = LogisticRegression()
# ----> 3 log_reg.fit(X_train, y_train)
#
# c:\users\91981\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1514             accept_large_sparse=solver != "liblinear",
#    1515         )
# -> 1516         check_classification_targets(y)
#    1517         self.classes_ = np.unique(y)
#    1518
#
# c:\users\91981\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     196         "multilabel-sequences",
#     197     ]:
# --> 198         raise ValueError("Unknown label type: %r" % y_type)
#     199
#     200
#
# ValueError: Unknown label type: 'continuous'

# %%
log_reg.score(X, Y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20928/1300712230.py in <module>
# ----> 1 log_reg.score(X, Y)
#
# c:\users\91981\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     640         from .metrics import accuracy_score
#     641
# --> 642         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     643
#     644     def _more_tags(self):
#
# c:\users\91981\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     423             Predicted class label per sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# c:\users\91981\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     406
#     407         X = self._validate_data(X, accept_sparse="csr", reset=False)
# --> 408         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     409         return scores.ravel() if scores.shape[1] == 1 else scores
#     410
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'
